# %%
import pymongo
from pymongo import MongoClient
client = MongoClient("mongodb+srv://wendy587941:teamone@cluster0.vfbrd.mongodb.net/TripAdvisor?retryWrites=true&w=majority")

db = client.get_database('TripAdvisor')

collection_name = db.Restaurant_comments
# collection_name = db.Restaurant_info

comment_details = collection_name.find()

# %%
from pandas import DataFrame
# convert the dictionary objects to dataframe
df = DataFrame(comment_details)
df
# Out:
#                              _id      id                   餐廳名稱  \
# 0       610f7abe23d1825d8858263c       0             "王" 保加利亞餐廳
# 1       610f7abe23d1825d8858263d       1             "王" 保加利亞餐廳
# 2       610f7abe23d1825d8858263e       2  1+1 Together Republic
# 3       610f7abe23d1825d8858263f       3          1010湘 - 天母三越店
# 4       610f7abe23d1825d88582640       4          1010湘 - 天母三越店
# ...                          ...     ...                    ...
# 162320  610f7af123d1825d885aa04c  162320          龐德羅莎牛沙拉（京華城店）
# 162321  610f7af123d1825d885aa04d  162321             龜山島阿興現撈海產店
# 162322  610f7af123d1825d885aa04e  162322             龜山島阿興現撈海產店
# 162323  610f7af123d1825d885aa04f  162323             龜山島阿興現撈海產店
# 162324  610f7af123d1825d885aa050  162324             龜山島阿興現撈海產店
#
#                   評論帳號  評論分數        評論標題  \
# 0              Grace C     5     台北的世外桃源
# 1             FuTehChu     3        高檔路線
# 2                 宇捷 鄧     3  有貓的餐廳，食物普通
# ...

# %%
columns=['_id']
df.drop(columns, axis=1, inplace=True)
df
# Out:
#             id                   餐廳名稱            評論帳號  評論分數        評論標題  \
# 0            0             "王" 保加利亞餐廳         Grace C     5     台北的世外桃源
# 1            1             "王" 保加利亞餐廳        FuTehChu     3        高檔路線
# 2            2  1+1 Together Republic            宇捷 鄧     3  有貓的餐廳，食物普通
# 3            3          1010湘 - 天母三越店   Odyssey809632     4      行軍砸了招牌
# 4            4          1010湘 - 天母三越店  Sightsee809995     5        開心用餐
# ...        ...                    ...             ...   ...         ...
# 162320  162320          龐德羅莎牛沙拉（京華城店）          Jean T     4       童年的回憶
# 162321  162321             龜山島阿興現撈海產店         Seewhom     4   新鮮美味的海產餐廳
# 162322  162322             龜山島阿興現撈海產店           uuzoe     4        新鮮好吃
# 162323  162323             龜山島阿興現撈海產店      racychiang     5          好吃
# 162324  162324             龜山島阿興現撈海產店          peltin     4  上菜速度快,美味新鮮
#
#                                                      評論內容
# ...

# %%
df.to_csv('./tripadvisor_comments.csv', index=None, encoding='utf-8_sig')

# %%
import pandas as pd
import jieba
import jieba.analyse
import operator
comments = pd.read_csv('tripadvisor_comments.csv')
jieba.load_userdict('<userdict file.txt>')
jieba.analyse.set_stop_words('< stopwords file.txt>')
# jieba.analyse.set_idf_path('<userdict file.txt>') #暫時不使用自定義idf

data=[]
for i in range(len(comments)):
    txt=comments['評論內容'][i]
    tags = jieba.analyse.extract_tags( txt ,withWeight=True, topK=5)
    data.append(tags)
    df2=pd.DataFrame(data)
    
                    
df2
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\TIBAME~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.572 seconds.
# Prefix dict has been built successfully.
#                           0                         1  \
# 0  (餐廳, 0.5313230001288889)  (特別, 0.5313230001288889)
# 1  (好吃, 1.0798079035466666)  (他們, 0.7969845001933333)
# 2  (白飯, 0.4511233019962264)  (電鍋, 0.4511233019962264)
# 3  (18, 0.4981153126208333)  (17, 0.4981153126208333)
# 4  (感謝, 1.7078239289857144)  (用餐, 1.3652674614457143)
# 5  (套餐, 0.7165930902546154)  (平常, 0.3747504162989744)
# 6    (家人, 0.87537158860625)    (餐點, 0.74717296893125)
# 7       (適合, 1.19547675029)      (不大想, 0.66037652357)
# 8      (藉由, 0.625719164545)     (這次家, 0.597738375145)
# 9  (餐食, 0.6291982896263157)  (選擇, 0.6291982896263157)
#
#                             2                           3  \
# 0  (葡萄酒, 0.36581318795555556)   (主人, 0.29352286147555556)
# ...
